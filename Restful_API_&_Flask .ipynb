# %% [markdown]
# THEORY QUESTIONS

# %% [markdown]
# 1. What is a RESTful API?
# - A RESTful API is a clean, scalable, and stateless way of building APIs by using standard HTTP methods, resource-based URLs, and common formats like JSON for data exchange. It's ideal for building web services that are easy to understand, use, and integrate.

# %% [markdown]
# 2. Explain the concept of API specification.
# - An API specification is a blueprint for how an API behaves. It defines endpoints, methods, inputs, outputs, and errors. Standards like OpenAPI (Swagger) make it easier to document, test, and integrate APIs consistently and accurately.
# - Documentation: Helps developers understand how to use the API.
#
# - Consistency: Ensures the API behaves predictably.
#
# - Automation: Tools like Swagger UI or Postman can generate docs and test APIs from specs.
#
# - Collaboration: Backend and frontend teams can work in parallel using the spec.

# %% [markdown]
# 3. What is Flask, and why is it popular for building APIs?
# - Flask is a lightweight, open-source Python web framework used to build web applications and APIs. It is based on Werkzeug (WSGI toolkit) and Jinja2 (template engine).
# - Flask is Popular for Building APIs:
# - Lightweight & Simple
#
#  Minimal boilerplate; you write only what you need.
#
#  Ideal for small to medium applications and APIs.
#
# - Flexible
#
#  Doesn’t force a particular project structure or tools.
#
#  You can use any database, authentication system, or frontend.
#
# - Built-in Development Server
#
#  Easy to test and debug without needing external setup.
#
# - Rich Ecosystem
#
#  Extensions like Flask-SQLAlchemy, Flask-RESTful, and Flask-JWT help build powerful APIs quickly.
#
# - Easy Routing
#
#  Simple route definition using decorators like @app.route('/api').
#
# - JSON Support
#
#  Built-in support for handling and returning JSON data using jsonify().
#
# - Great for REST APIs
#
#  Clean URL mapping and support for all HTTP methods make it perfect for RESTful APIs.

# %% [markdown]
# 4. What is routing in Flask?
# - Routing in Flask refers to the process of mapping URLs to functions. These functions are called view functions, and they define what should happen when a user visits a specific URL in your application.

# %% [markdown]
# 5. How do you create a simple Flask application?
# - Install:Flask	pip install Flask
# - Create a file:app.py
# - Define a route:Use @app.route('/')
# - Run the app	python:app.py
# - Open in browser

# %% [markdown]
# 6. What are HTTP methods used in RESTful APIs?
# - GET: Read data
#
# - POST: Create data
#
# - PUT: Full update
#
# - PATCH: Partial update
#
# - DELETE: Remove data
#
# - OPTIONS: Check supported methods

# %% [markdown]
# 7. What is the purpose of the @app.route() decorator in Flask?
# - Maps URLs to functions: It connects a web address (route) with the code that should run.
#
# - Defines endpoint behavior: Controls what content or response is returned for that URL.
#
# - Supports dynamic routing: You can capture parts of the URL as variables.
#
# - Specifies HTTP methods: You can restrict routes to certain HTTP methods like GET, POST.

# %% [markdown]
# 8. What is the difference between GET and POST HTTP methods?
# - ![image.png](data:image/png;base64,...)

# %% [markdown]
# 9. How do you handle errors in Flask APIs?
# - Handling errors effectively in Flask APIs is crucial for building robust and user-friendly applications. Flask provides several mechanisms to manage errors gracefully, ensuring that clients receive meaningful feedback and that developers can debug issues efficiently.
# - Use Custom Error Handlers: Define custom error handlers using the @app.errorhandler decorator to return structured JSON responses. This ensures consistency and clarity in error messages.
#
# - Create Custom Exception Classes: Implement custom exception classes for application-specific errors. This allows for more granular control over error handling and response generation.
#
# - Return Appropriate HTTP Status Codes: Ensure that each error response includes the correct HTTP status code to accurately represent the nature of the error.
#
#
# - Implement Logging: Log errors using Python's built-in logging module or integrate with external logging services. Proper logging aids in monitoring and debugging.
#
#
# - Avoid Exposing Internal Details: In production, prevent the exposure of stack traces or internal error details to clients. Instead, provide generic error messages and log the detailed errors internally.

# %% [markdown]
# 10. How do you connect Flask to a SQL database?
# - Install Flask and Flask-SQLAlchemy
# -	Configure SQLALCHEMY_DATABASE_URI
# -	Define models with db.Model
# -	Use db.create_all() to set up tables
# -	Perform CRUD operations

# %% [markdown]
# 11. What is the role of Flask-SQLAlchemy?
# - Flask-SQLAlchemy helps manage connections to a variety of relational databases like:
#
# - SQLite
#
# - MySQL
#
# - PostgreSQL
#
# - Oracle
#
# - Microsoft SQL Server

# %% [markdown]
# 12. What are Flask blueprints, and how are they useful?
# - Flask Blueprints are a way to organize a Flask application into smaller, reusable components or modules. They allow you to break a large application into distinct parts, each with its own views, templates, static files, and more.
#
# - Blueprints help organize your Flask app into modules.
#
# - They encourage reusable, scalable, and clean code.
#
# - Great for both small and large Flask applications.

# %% [markdown]
# 13. What is the purpose of Flask's request object?
# - The request object in Flask is used to access data sent by the client to the server during an HTTP request. It provides a simple interface to handle request-related information such as form data, query parameters, JSON payloads, headers, and more.
# The request object is critical for building dynamic web applications and RESTful APIs. It gives your Flask app the ability to:
#
# - Handle user input
#
# - Process API calls
#
# - Authenticate users
#
# - Respond based on client behavior

# %% [markdown]
# 14. How do you create a RESTful API endpoint using Flask?
#
# - Install Flask: pip install Flask
#
# Import Flask, request, and jsonify
#
# Initialize Flask app: app = Flask(__name__)
#
# Define API routes with @app.route() specifying URL and HTTP methods (GET, POST, PUT, DELETE)
#
# Use request.get_json() to get JSON data from client (for POST/PUT)
#
# Return JSON responses using jsonify()
#
# Handle CRUD operations:
#
# GET to fetch data
#
# POST to create new data
#
# PUT to update existing data
#
# DELETE to remove data
#
# Run app with app.run(debug=True)
#
# Test API with tools like Postman or curl

# %% [markdown]
# 15.  What is the purpose of Flask's jsonify() function?
#
# - The purpose of Flask’s jsonify() function is to:
#
# Convert Python data structures (like dictionaries or lists) into a JSON-formatted HTTP response.
#
# Automatically set the Content-Type header to application/json so clients know the response is JSON.
#
# Handle JSON serialization safely, including special data types.
#
# Simplify returning JSON responses in Flask APIs without manually calling json.dumps() or setting headers.

# %% [markdown]
# 16. Explain Flask's url_for() function.
# - Flask’s url_for() function is used to dynamically build URLs for your application’s routes based on the function name that handles the route.
# - Purpose of url_for()
# - Generates URLs by referencing the view function name, avoiding hardcoding URLs in templates or code.
#
# - Automatically handles URL building including any variable parts (like IDs or slugs).
#
# - Adapts URLs if you change route patterns, so you don’t have to manually update links.
#
# - Supports passing query parameters dynamically.

# %% [markdown]
# 17. How does Flask handle static files (CSS, JavaScript, etc.)?
# - Flask handles static files (like CSS, JavaScript, images) using a special folder named static in your project directory.
# - By default, Flask looks for static files inside a folder called static/ located at the root of your Flask project.
#
# - You place your CSS, JS, images, or other static assets inside this folder.
#
# - These files are automatically served at the URL path /static/.

# %% [markdown]
# 18. What is an API specification, and how does it help in building a Flask API?
# - An API specification is a formal, structured document that defines how an API behaves. It describes:
#
# - The available endpoints (URLs)
#
# - Supported HTTP methods (GET, POST, etc.)
#
# - Required and optional parameters
#
# - Request and response data formats (JSON, XML, etc.)
#
# - Authentication methods, error codes, and more
#
# Clear contract: Provides a clear agreement between frontend and backend teams on how the API works.
#
# Design first: Helps you design the API before writing code, ensuring better planning and consistency.
#
# Documentation: Serves as up-to-date documentation automatically or manually generated from the spec.
#
# Validation: Enables automatic request/response validation to catch errors early.
#
# Testing & Automation: Facilitates automated testing, code generation, and client SDK generation.
#
# Consistency: Ensures consistent API behavior across different endpoints and versions.

# %% [markdown]
# 19. What are HTTP status codes, and why are they important in a Flask API?
#
# - HTTP status codes are standardized three-digit codes sent by a server in response to a client's HTTP request. They indicate the result of the request — whether it was successful, failed, redirected, or encountered an error.
# - Communicate outcome: Inform the client if their request succeeded, failed, or needs correction.
#
# - Enable error handling: Clients can respond appropriately based on status codes (retry, show error, redirect).
#
# - RESTful standards: Following standard status codes makes your API predictable and interoperable.
#
# - Debugging & monitoring: Easy to track issues by looking at response codes.
#
# - SEO & caching: Proper status codes help browsers and search engines behave correctly.

# %% [markdown]
# 20. How do you handle POST requests in Flask?
# - Handling POST requests in Flask involves defining a route that accepts the POST method and accessing the data sent by the client (usually form data or JSON).
# - To handle POST requests in Flask, define a route accepting POST, then use request.form or request.get_json() to read incoming data.

# %% [markdown]
# 21. How would you secure a Flask API?
# - Securing a Flask API involves multiple layers and best practices to protect it from unauthorized access, data breaches, and attacks.
# - Use HTTPS
#
#   Always serve your API over HTTPS to encrypt data in transit.
#
#   Use SSL/TLS certificates.
#
# - Authentication
#
#   Implement token-based authentication like JWT (JSON Web Tokens) or OAuth2.
#
#   Use Flask extensions like Flask-JWT-Extended or Flask-OAuthlib.
#
#   Require clients to send tokens in headers (Authorization: Bearer <token>).
#
# - Authorization
#
#   Define roles and permissions to restrict access to resources.
#
#  Verify user permissions before processing requests.
#
# - Input Validation & Sanitization
#
#  Validate incoming data to prevent injection attacks (SQL injection, XSS).
#
#  Use libraries like marshmallow for schema validation.
#
# - Rate Limiting
#
#  Protect against brute force and DDoS attacks.
#
#  Use Flask-Limiter to limit the number of requests per IP or user.
#
# - Use Secure Headers
#
#  Set HTTP headers like Content-Security-Policy, X-Content-Type-Options, and Strict-Transport-Security.
#
#  Use Flask-Talisman extension to simplify setting security headers.
#
# - Error Handling
#
#  Avoid exposing sensitive information in error messages.
#
#  Customize error responses without revealing stack traces.
#
# - Keep Dependencies Updated
#
#  Regularly update Flask and third-party libraries to patch security vulnerabilities.
#
# - CORS Configuration
#
#  Use Flask-CORS to configure Cross-Origin Resource Sharing securely.
#
#  Allow only trusted origins.

# %% [markdown]
# 22. What is the significance of the Flask-RESTful extension?
# - Resource-based abstraction: Lets you organize your API endpoints as resources (classes), making code cleaner and easier to manage.
#
#   Automatic request parsing: Simplifies handling and validating input data (query parameters, JSON payloads) with built-in request parsers.
#
#  Built-in support for HTTP methods: Easily define handlers for GET, POST, PUT, DELETE inside resource classes.
#
#  Automatic JSON responses: Converts returned dictionaries into JSON responses with proper headers.
#
#  Error handling: Provides helpful error responses with minimal effort.
#
#  Integration: Works seamlessly with Flask, letting you add REST API functionality without boilerplate code.

# %% [markdown]
# 23. What is the role of Flask’s session object?
# - Store user-specific data: Keep track of user info like login status, preferences, shopping cart contents, etc.
#
#  Persist data between requests: Data in session survives across different HTTP requests during the user’s visit.
#
#  Secure storage: By default, Flask stores session data in a signed (and optionally encrypted) cookie to prevent tampering.
#
#  Easy access: session behaves like a Python dictionary, making it simple to set and retrieve values.

# %% [markdown]
# PRACTICAL QUESTIONS

# %%
pip install Flask

# %%
#1. How do you create a basic Flask application?
from flask import Flask
app = Flask(__name__)
@app.route('/')
def home():
    return "Hello, Flask!"
if __name__ == '__main__':
    app.run(debug=True)

# %%
#2. How do you serve static files like images or CSS in Flask?
from flask import Flask, url_for, render_template_string

app = Flask(__name__)

@app.route('/')
def home():
    # Simple HTML referencing static CSS and image files
    html = '''
    <html>
      <head>
        <link rel="stylesheet" type="text/css" href="{{ url_for('static', filename='css/style.css') }}">
      </head>
      <body>
        <h1>Welcome to Flask Static Files!</h1>
        <img src="{{ url_for('static', filename='images/logo.png') }}" alt="Logo" width="200">
      </body>
    </html>
    '''
    return render_template_string(html)

if __name__ == '__main__':
    app.run(debug=True)

# %%
#3. How do you define different routes with different HTTP methods in Flask?
from flask import Flask, request
app = Flask(__name__)
@app.route('/hello', methods=['GET'])
def hello():
    return "Hello, GET request!"
@app.route('/submit', methods=['POST'])
def submit():
    data = request.form.get('data', 'No data sent')
    return f"Received POST data: {data}"
@app.route('/both', methods=['GET', 'POST'])
def both_methods():
    if request.method == 'POST':
        return "This is a POST request"
    else:
        return "This is a GET request"
if __name__ == '__main__':
    app.run(debug=True)

# %%
#4. How do you render HTML templates in Flask?
from flask import Flask, render_template
app = Flask(__name__)
@app.route('/')
def home():
    return render_template('hello.html', name="Alice")
if __name__ == '__main__':
    app.run(debug=True)

# %%
#5. How can you generate URLs for routes in Flask using url_for?
from flask import Flask, url_for
app = Flask(__name__)
@app.route('/')
def home():
    return "Home page"
@app.route('/user/<username>')
def profile(username):
    return f"Profile page of {username}"
@app.route('/show_urls')
def show_urls():
    home_url = url_for('home')
    profile_url = url_for('profile', username='alice')
    return f"Home URL: {home_url} <br> Profile URL: {profile_url}"
if __name__ == '__main__':
    app.run(debug=True)

# %%
#6. How do you handle forms in Flask?
from flask import Flask, render_template, request
app = Flask(__name__)
@app.route('/form', methods=['GET', 'POST'])
def form():
    if request.method == 'POST':
        name = request.form.get('name')
        email = request.form.get('email')
        return f"Received: Name = {name}, Email = {email}"
    return render_template('form.html')
if __name__ == '__main__':
    app.run(debug=True)

# %%
#7. How can you validate form data in Flask?
from flask import Flask, request, render_template_string
app = Flask(__name__)
@app.route('/submit', methods=['GET', 'POST'])
def submit():
    error = None
    if request.method == 'POST':
        name = request.form.get('name', '').strip()
        if not name:
            error = "Name is required."
        elif len(name) < 3:
            error = "Name must be at least 3 characters."
        else:
            return f"Hello, {name}!"
    html = '''
    <form method="POST">
        Name: <input type="text" name="name" />
        <input type="submit" value="Submit" />
    </form>
    {% if error %}
    <p style="color:red;">{{ error }}</p>
    {% endif %}
    '''
    return render_template_string(html, error=error)
if __name__ == '__main__':
    app.run(debug=True)

# %%
#8. How do you manage sessions in Flask?
from flask import Flask, session, redirect, url_for, request
app = Flask(__name__)
app.secret_key = 'secret!'
@app.route('/login', methods=['GET', 'POST'])
def login():
    if request.method == 'POST':
        username = request.form['username']
        session['username'] = username
        return redirect(url_for('profile'))
    return '''
        <form method="post">
            Username: <input name="username" />
            <input type="submit" />
        </form>
    '''
@app.route('/profile')
def profile():
    if 'username' in session:
        return f"Logged in as {session['username']}"
    return "You are not logged in"
@app.route('/logout')
def logout():
    session.pop('username', None)
    return "Logged out"
if __name__ == '__main__':
    app.run(debug=True)

# %%
#9. How do you redirect to a different route in Flask?
from flask import Flask, redirect, url_for
app = Flask(__name__)
@app.route('/')
def home():
    return "This is the home page."
@app.route('/go-to-home')
def go_to_home():
    return redirect(url_for('home'))
if __name__ == '__main__':
    app.run(debug=True)

# %%
#10. How do you handle errors in Flask (e.g., 404)?
from flask import Flask, render_template
app = Flask(__name__)
@app.route('/')
def home():
    return "Welcome to the home page!"
@app.errorhandler(404)
def page_not_found(error):
    return "<h1>404 Error</h1><p>Sorry, the page you requested was not found.</p>", 404
if __name__ == '__main__':
    app.run(debug=True)

# %%
#11. How do you structure a Flask app using Blueprints?
from flask import Flask
from blog import blog_bp
app = Flask(__name__)
app.register_blueprint(blog_bp, url_prefix='/blog')
@app.route('/')
def home():
    return "Welcome to the main page!"
if __name__ == '__main__':
    app.run(debug=True)

# %%
#12. How do you define a custom Jinja filter in Flask?
from flask import Flask, render_template_string
app = Flask(__name__)
def reverse_string(s):
    return s[::-1]
app.jinja_env.filters['reverse'] = reverse_string
@app.route('/')
def home():
    return render_template_string('Original: {{ text }} <br> Reversed: {{ text | reverse }}', text="hello")
if __name__ == '__main__':
    app.run(debug=True)

# %%
#13. How can you redirect with query parameters in Flask?
from flask import Flask, redirect, url_for, request
app = Flask(__name__)
@app.route('/')
def home():
    return redirect(url_for('greet', name='Alice', age=22))\
@app.route('/greet')
def greet():
    name = request.args.get('name')
    age = request.args.get('age')
    return f"Hello, {name}! You are {age} years old."
if __name__ == '__main__':
    app.run(debug=True)

# %%
#14. How do you return JSON responses in Flask?
from flask import Flask, jsonify
app = Flask(__name__)
@app.route('/api/data')
def get_data():
    data = {
        "name": "Prayag",
        "age": 25,
        "status": "active"
    }
    return jsonify(data)
if __name__ == '__main__':
    app.run(debug=True)

# %%
#15. How do you capture URL parameters in Flask?
from flask import Flask
app = Flask(__name__)
@app.route('/user/<username>')
def show_user(username):
    return f"Hello, {username}!"
if __name__ == '__main__':
    app.run(debug=True)
